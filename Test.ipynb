# %% [markdown]
# # Test with IPython Notebook and Online Sharing
#
# This is a test to see if this works well.
#
# \begin{equation}
# E = \gamma mc^2
# \end{equation}

# %%
import matplotlib.pyplot as plt
from numpy import linspace, sin, cos, pi
# %matplotlib inline

# %% [markdown]
# ## Plot some fancy functions

# %%
x = linspace(0, 2 * pi, endpoint=False)

y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, label="$\sin(x)$")
plt.plot(x, y2, label="$\cos(x)$")
plt.legend(loc='lower left')
plt.show()
